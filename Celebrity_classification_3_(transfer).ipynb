# %%
import torch
device = 'cuda' if torch.cuda.is_available() else 'cpu' # device 배정
torch.manual_seed(42)
if device == 'cuda':
  torch.cuda.manual_seed_all(42)
device
# Out:
# 'cuda'

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from matplotlib import rc
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
import torchvision.models as models
from efficientnet_pytorch import EfficientNet

# device = torch.device('mps:0' if torch.backends.mps.is_available() else 'cpu')
# rc('font', family='AppleGothic')
# plt.rcParams['axes.unicode_minus'] = False

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from matplotlib import rc
import numpy as np

# plt.rcParams['font.family'] = 'NanumBarunGothic'

# %% [markdown]
# ### 김태희 vs 김혜수 전이학습

# %% [markdown]
# - 마동석vs송중기 분류 모델을 김태희vs김혜수 전이학습에 이용

# %% [markdown]
# #### 데이터 불러오기

# %%
train_transforms = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(degrees=20),
    transforms.RandomResizedCrop(size=448, scale=(0.8, 1.0)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
valid_transforms = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transforms = transforms.Compose([
    transforms.Resize((448, 448)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 데이터셋 경로 설정
dataset_path = 'C://Users/user/Desktop/딥러닝/project_kk'

# ImageFolder를 사용하여 전체 데이터셋을 불러옵니다.
train_dataset = ImageFolder(dataset_path + '/train', transform=train_transforms)
val_dataset = ImageFolder(dataset_path + '/val', transform=valid_transforms)
# test_dataset = ImageFolder(dataset_path + '/test', transform=test_transforms)

# DataLoader 설정
batch_size = 16
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=3)
val_loader = DataLoader(val_dataset, batch_size=batch_size, num_workers=3)
# test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
imgs, labels = next(iter(train_loader))

fig, axes = plt.subplots(4, 8, figsize=(20,10))

mean=[0.485, 0.456, 0.406]
std=[0.229, 0.224, 0.225]

for img, label, ax in zip(imgs, labels, axes.flatten()):
    ax.set_title(label.item())
    ax.imshow(img.permute(1,2,0).numpy() * std + mean)
    ax.axis('off')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# #### 전체 학습 ver

# %%
import time

# 학습 시작 시간 기록
start_time = time.time()

model = EfficientNet.from_pretrained('efficientnet-b1', num_classes=2)
model = model.to(device)

# 손실 함수와 옵티마이저 설정
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# 리스트 초기화
effb1_train_acc_lst = []
effb1_train_loss_lst = []
effb1_val_acc_lst = []
effb1_val_loss_lst = []

state = {}

# 모델 훈련
epochs = 5
for epoch in range(1, epochs+1):

    train_loss = 0
    total = 0
    correct = 0
    train_acc = 0

    model.train()

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)

        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        # 정확도 계산
        _, predicted = torch.max(outputs, 1)  # 가장 높은 확률을 가진 클래스 선택
        total += labels.size(0)
        train_acc += (predicted == labels).sum().item()

    train_loss = round(train_loss / len(train_loader), 3)  # 미니배치 수로 나누어 평균을 계산
    train_acc = round((train_acc / total) * 100, 2)  # 백분율로 변환

    print(f'Trainset {epoch}/{epochs} Loss: {train_loss}, Accuracy: {train_acc}%')
    effb1_train_acc_lst.append(train_acc)
    effb1_train_loss_lst.append(train_loss)

    # 검증 데이터셋에 대한 손실과 정확도 계산
    val_loss = 0
    val_total = 0
    val_correct = 0
    val_acc = 0

    model.eval()
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            val_loss += criterion(outputs, labels).item()

            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_acc += (predicted == labels).sum().item()

    val_loss = round(val_loss / len(val_loader), 3)  # 검증 데이터셋의 손실 평균 계산
    val_acc = round((val_acc / val_total) * 100, 2)  # 검증 데이터셋의 정확도 계산

    print(f'Validation {epoch}/{epochs} Loss: {val_loss}, Accuracy: {val_acc}%')
    print()

    effb1_val_acc_lst.append(val_acc)
    effb1_val_loss_lst.append(val_loss)

    if np.max(effb1_val_acc_lst) <= val_acc:
        state['epoch'] = epoch
        state['net'] = model.state_dict()

        state['train_loss'] = train_loss
        state['val_loss'] = val_loss

        state['train_acc'] = train_acc
        state['val_acc'] = val_acc

end_time = time.time()

# 전체 학습 시간 계산 (종료 시간 - 시작 시간)
training_time_seconds = end_time - start_time

# 시, 분, 초로 변환
training_time_minutes = training_time_seconds // 60
training_time_hours = training_time_minutes // 60

print(f"Total training time: {training_time_seconds} seconds")
print(f"Total training time: {training_time_minutes} minutes")
print(f"Total training time: {training_time_hours} hours")
print(f"Total training time: {training_time_hours} H {training_time_minutes - (60 * training_time_hours)} m")

# 모델 저장
torch.save(state, 'C://Users/user/Desktop/딥러닝/학습모델/full_김김_448_efficientb1_{}_{}.pth'.format(str(state['epoch']), str(state['val_acc'])))
# Out:
# Loaded pretrained weights for efficientnet-b1
# Trainset 1/5 Loss: 0.463, Accuracy: 79.37%
# Validation 1/5 Loss: 0.404, Accuracy: 83.3%
#
# Trainset 2/5 Loss: 0.23, Accuracy: 90.52%
# Validation 2/5 Loss: 0.219, Accuracy: 91.92%
#
# Trainset 3/5 Loss: 0.151, Accuracy: 94.18%
# Validation 3/5 Loss: 0.168, Accuracy: 93.36%
#
# Trainset 4/5 Loss: 0.122, Accuracy: 95.41%
# Validation 4/5 Loss: 0.18, Accuracy: 94.25%
#
# Trainset 5/5 Loss: 0.105, Accuracy: 96.16%
# Validation 5/5 Loss: 0.15, Accuracy: 95.51%
#
# Total training time: 191.29351997375488 seconds
# Total training time: 3.0 minutes
# Total training time: 0.0 hours
# Total training time: 0.0 H 3.0 m

# %% [markdown]
# ##### Acc and Loss 시각화

# %%
# 정확도 및 손실을 그래프로 시각화
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(effb1_train_acc_lst, label='Train Accuracy')
plt.plot(effb1_val_acc_lst, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(effb1_train_loss_lst, label='Train Loss')
plt.plot(effb1_val_loss_lst, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# #### Conv 하위층 및 Classifier ver

# %%
import time
import torch.optim as optim

start_time = time.time()

# 모델 불러오기
model_path = 'C://Users/user/Desktop/딥러닝/학습모델/full_마송_448_efficientb1_38_98.71.pth'

# 모델 정의 (모델 아키텍처와 동일하게 정의해야 함)
model = EfficientNet.from_name('efficientnet-b1', num_classes=2)
model.to(device)

# 저장된 모델 가중치 불러오기
checkpoint = torch.load(model_path, map_location=device)
model.load_state_dict(checkpoint['net'])

# 모델의 Convolution 층을 학습 가능하도록 설정
start_training = False  # 학습 시작 플래그

for name, param in model.named_parameters():
    if '_blocks.20._expand_conv' in name:  # 학습을 시작할 층의 이름을 식별
        start_training = True
    if start_training:
        param.requires_grad = True
    else:
        param.requires_grad = False

# 필요한 옵티마이저 정의
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.0001)

# 손실 함수 정의
criterion = nn.CrossEntropyLoss()

# 리스트 초기화
effb1_train_acc_lst = []
effb1_train_loss_lst = []
effb1_val_acc_lst = []
effb1_val_loss_lst = []

state = {}

# 모델 훈련
epochs = 50
for epoch in range(1, epochs+1):

    train_loss = 0
    total = 0
    correct = 0
    train_acc = 0

    model.train()

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images).to(device)

        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        # 정확도 계산
        _, predicted = torch.max(outputs, 1)  # 가장 높은 확률을 가진 클래스 선택
        total += labels.size(0)
        train_acc += (predicted == labels).sum().item()

    train_loss = round(train_loss / len(train_loader), 3)  # 미니배치 수로 나누어 평균을 계산
    train_acc = round((train_acc / total) * 100, 2)  # 백분율로 변환

    print(f'Trainset {epoch}/{epochs} Loss: {train_loss}, Accuracy: {train_acc}%')
    effb1_train_acc_lst.append(train_acc)
    effb1_train_loss_lst.append(train_loss)

    # 검증 데이터셋에 대한 손실과 정확도 계산
    val_loss = 0
    val_total = 0
    val_correct = 0
    val_acc = 0

    model.eval()
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            val_loss += criterion(outputs, labels).item()

            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_acc += (predicted == labels).sum().item()

    val_loss = round(val_loss / len(val_loader), 3)  # 검증 데이터셋의 손실 평균 계산
    val_acc = round((val_acc / val_total) * 100, 2)  # 검증 데이터셋의 정확도 계산

    print(f'Validation {epoch}/{epochs} Loss: {val_loss}, Accuracy: {val_acc}%')
    print()

    effb1_val_acc_lst.append(val_acc)
    effb1_val_loss_lst.append(val_loss)

    if np.max(effb1_val_acc_lst) <= val_acc:
        state['epoch'] = epoch
        state['net'] = model.state_dict()

        state['train_loss'] = train_loss
        state['val_loss'] = val_loss

        state['train_acc'] = train_acc
        state['val_acc'] = val_acc

end_time = time.time()

# 전체 학습 시간 계산 (종료 시간 - 시작 시간)
training_time_seconds = end_time - start_time

# 시, 분, 초로 변환
training_time_minutes = training_time_seconds // 60
training_time_hours = training_time_minutes // 60

print(f"Total training time: {training_time_seconds} seconds")
print(f"Total training time: {training_time_minutes} minutes")
print(f"Total training time: {training_time_hours} hours")
print(f"Total training time: {training_time_hours} H {training_time_minutes - (60 * training_time_hours)} m")

# 모델 저장
torch.save(state, 'C://Users/user/Desktop/딥러닝/학습모델/middle_마송_448_efficientb1_{}_{}.pth'.format(str(state['epoch']), str(state['val_acc'])))
# Out:
# Trainset 1/50 Loss: 1.24, Accuracy: 61.99%
# Validation 1/50 Loss: 0.688, Accuracy: 65.17%
#
# Trainset 2/50 Loss: 0.473, Accuracy: 78.72%
# Validation 2/50 Loss: 0.497, Accuracy: 78.82%
#
# Trainset 3/50 Loss: 0.383, Accuracy: 83.36%
# Validation 3/50 Loss: 0.409, Accuracy: 82.76%
#
# Trainset 4/50 Loss: 0.31, Accuracy: 86.8%
# Validation 4/50 Loss: 0.382, Accuracy: 83.12%
#
# Trainset 5/50 Loss: 0.272, Accuracy: 87.95%
# Validation 5/50 Loss: 0.355, Accuracy: 85.46%
#
# Trainset 6/50 Loss: 0.241, Accuracy: 90.2%
# Validation 6/50 Loss: 0.325, Accuracy: 85.64%
#
# Trainset 7/50 Loss: 0.208, Accuracy: 92.19%
# Validation 7/50 Loss: 0.323, Accuracy: 87.79%
#
# Trainset 8/50 Loss: 0.174, Accuracy: 93.2%
# Validation 8/50 Loss: 0.285, Accuracy: 88.33%
#
# Trainset 9/50 Loss: 0.177, Accuracy: 92.54%
# Validation 9/50 Loss: 0.342, Accuracy: 89.05%
#
# Trainset 10/50 Loss: 0.152, Accuracy: 93.95%
# Validation 10/50 Loss: 0.265, Accuracy: 89.41%
#
# Trainset 11/50 Loss: 0.12, Accuracy: 95.14%
# Validation 11/50 Loss: 0.283, Accuracy: 89.23%
#
# Trainset 12/50 Loss: 0.127, Accuracy: 95.23%
# Validation 12/50 Loss: 0.273, Accuracy: 90.31%
#
# Trainset 13/50 Loss: 0.118, Accuracy: 95.81%
# Validation 13/50 Loss: 0.257, Accuracy: 90.13%
#
# Trainset 14/50 Loss: 0.097, Accuracy: 96.56%
# Validation 14/50 Loss: 0.252, Accuracy: 91.38%
#
# Trainset 15/50 Loss: 0.079, Accuracy: 97.4%
# Validation 15/50 Loss: 0.28, Accuracy: 91.2%
#
# Trainset 16/50 Loss: 0.087, Accuracy: 96.64%
# Validation 16/50 Loss: 0.289, Accuracy: 89.59%
#
# Trainset 17/50 Loss: 0.095, Accuracy: 96.51%
# Validation 17/50 Loss: 0.245, Accuracy: 92.46%
#
# Trainset 18/50 Loss: 0.076, Accuracy: 97.17%
# Validation 18/50 Loss: 0.279, Accuracy: 91.56%
#
# Trainset 19/50 Loss: 0.069, Accuracy: 97.62%
# Validation 19/50 Loss: 0.277, Accuracy: 90.84%
#
# Trainset 20/50 Loss: 0.075, Accuracy: 97.0%
# Validation 20/50 Loss: 0.317, Accuracy: 91.02%
#
# Trainset 21/50 Loss: 0.062, Accuracy: 97.53%
# Validation 21/50 Loss: 0.315, Accuracy: 90.84%
#
# Trainset 22/50 Loss: 0.063, Accuracy: 97.35%
# Validation 22/50 Loss: 0.334, Accuracy: 88.87%
#
# Trainset 23/50 Loss: 0.057, Accuracy: 97.88%
# Validation 23/50 Loss: 0.301, Accuracy: 91.02%
#
# Trainset 24/50 Loss: 0.043, Accuracy: 98.41%
# Validation 24/50 Loss: 0.295, Accuracy: 91.92%
#
# Trainset 25/50 Loss: 0.055, Accuracy: 97.92%
# Validation 25/50 Loss: 0.379, Accuracy: 89.95%
#
# Trainset 26/50 Loss: 0.068, Accuracy: 97.66%
# Validation 26/50 Loss: 0.328, Accuracy: 90.48%
#
# Trainset 27/50 Loss: 0.03, Accuracy: 99.12%
# Validation 27/50 Loss: 0.275, Accuracy: 91.38%
#
# Trainset 28/50 Loss: 0.041, Accuracy: 98.23%
# Validation 28/50 Loss: 0.27, Accuracy: 91.2%
#
# Trainset 29/50 Loss: 0.034, Accuracy: 98.98%
# Validation 29/50 Loss: 0.324, Accuracy: 90.48%
#
# Trainset 30/50 Loss: 0.036, Accuracy: 98.68%
# Validation 30/50 Loss: 0.28, Accuracy: 91.74%
#
# Trainset 31/50 Loss: 0.042, Accuracy: 98.23%
# Validation 31/50 Loss: 0.258, Accuracy: 91.92%
#
# Trainset 32/50 Loss: 0.031, Accuracy: 99.12%
# Validation 32/50 Loss: 0.308, Accuracy: 90.48%
#
# Trainset 33/50 Loss: 0.039, Accuracy: 98.32%
# Validation 33/50 Loss: 0.256, Accuracy: 92.1%
#
# Trainset 34/50 Loss: 0.032, Accuracy: 98.9%
# Validation 34/50 Loss: 0.293, Accuracy: 91.38%
#
# Trainset 35/50 Loss: 0.037, Accuracy: 98.68%
# Validation 35/50 Loss: 0.29, Accuracy: 91.38%
#
# Trainset 36/50 Loss: 0.036, Accuracy: 98.68%
# Validation 36/50 Loss: 0.301, Accuracy: 92.28%
#
# Trainset 37/50 Loss: 0.037, Accuracy: 98.76%
# Validation 37/50 Loss: 0.301, Accuracy: 91.74%
#
# Trainset 38/50 Loss: 0.027, Accuracy: 98.85%
# Validation 38/50 Loss: 0.292, Accuracy: 92.46%
#
# Trainset 39/50 Loss: 0.023, Accuracy: 99.21%
# Validation 39/50 Loss: 0.337, Accuracy: 92.82%
#
# Trainset 40/50 Loss: 0.031, Accuracy: 99.03%
# Validation 40/50 Loss: 0.285, Accuracy: 92.1%
#
# Trainset 41/50 Loss: 0.036, Accuracy: 98.63%
# Validation 41/50 Loss: 0.392, Accuracy: 91.74%
#
# Trainset 42/50 Loss: 0.024, Accuracy: 99.07%
# Validation 42/50 Loss: 0.302, Accuracy: 92.28%
#
# Trainset 43/50 Loss: 0.021, Accuracy: 99.43%
# Validation 43/50 Loss: 0.297, Accuracy: 92.1%
#
# Trainset 44/50 Loss: 0.022, Accuracy: 99.25%
# Validation 44/50 Loss: 0.323, Accuracy: 91.92%
#
# Trainset 45/50 Loss: 0.025, Accuracy: 99.16%
# Validation 45/50 Loss: 0.345, Accuracy: 91.2%
#
# Trainset 46/50 Loss: 0.019, Accuracy: 99.56%
# Validation 46/50 Loss: 0.345, Accuracy: 92.1%
#
# Trainset 47/50 Loss: 0.032, Accuracy: 98.9%
# Validation 47/50 Loss: 0.265, Accuracy: 92.82%
#
# Trainset 48/50 Loss: 0.033, Accuracy: 99.29%
# Validation 48/50 Loss: 0.332, Accuracy: 92.1%
#
# Trainset 49/50 Loss: 0.031, Accuracy: 98.72%
# Validation 49/50 Loss: 0.289, Accuracy: 92.46%
#
# Trainset 50/50 Loss: 0.028, Accuracy: 99.03%
# Validation 50/50 Loss: 0.265, Accuracy: 92.1%
#
# Total training time: 1477.5557112693787 seconds
# Total training time: 24.0 minutes
# Total training time: 0.0 hours
# Total training time: 0.0 H 24.0 m

# %%
# # 모델 불러오기
# model_path = 'C://Users/user/Desktop/딥러닝/학습모델/full_마송_448_efficientb1_38_98.71.pth'

# # 모델 정의 (모델 아키텍처와 동일하게 정의해야 함)
# model = EfficientNet.from_name('efficientnet-b1', num_classes=2)
# model.to(device)

# # 저장된 모델 가중치 불러오기
# checkpoint = torch.load(model_path, map_location=device)
# model.load_state_dict(checkpoint['net'])

# %%
for name, param in model.named_parameters():
    if param.requires_grad == True:
        print(f'학습 대상인 층: {name}')
    else:
        print(f'동결된 층: {name}')
# Out:
# 동결된 층: _conv_stem.weight
# 동결된 층: _bn0.weight
# 동결된 층: _bn0.bias
# 동결된 층: _blocks.0._depthwise_conv.weight
# 동결된 층: _blocks.0._bn1.weight
# 동결된 층: _blocks.0._bn1.bias
# 동결된 층: _blocks.0._se_reduce.weight
# 동결된 층: _blocks.0._se_reduce.bias
# 동결된 층: _blocks.0._se_expand.weight
# 동결된 층: _blocks.0._se_expand.bias
# 동결된 층: _blocks.0._project_conv.weight
# 동결된 층: _blocks.0._bn2.weight
# 동결된 층: _blocks.0._bn2.bias
# 동결된 층: _blocks.1._depthwise_conv.weight
# 동결된 층: _blocks.1._bn1.weight
# 동결된 층: _blocks.1._bn1.bias
# 동결된 층: _blocks.1._se_reduce.weight
# 동결된 층: _blocks.1._se_reduce.bias
# 동결된 층: _blocks.1._se_expand.weight
# 동결된 층: _blocks.1._se_expand.bias
# 동결된 층: _blocks.1._project_conv.weight
# 동결된 층: _blocks.1._bn2.weight
# 동결된 층: _blocks.1._bn2.bias
# 동결된 층: _blocks.2._expand_conv.weight
# 동결된 층: _blocks.2._bn0.weight
# 동결된 층: _blocks.2._bn0.bias
# 동결된 층: _blocks.2._depthwise_conv.weight
# 동결된 층: _blocks.2._bn1.weight
# 동결된 층: _blocks.2._bn1.bias
# 동결된 층: _blocks.2._se_reduce.weight
# 동결된 층: _blocks.2._se_reduce.bias
# 동결된 층: _blocks.2._se_expand.weight
# 동결된 층: _blocks.2._se_expand.bias
# 동결된 층: _blocks.2._project_conv.weight
# 동결된 층: _blocks.2._bn2.weight
# 동결된 층: _blocks.2._bn2.bias
# 동결된 층: _blocks.3._expand_conv.weight
# 동결된 층: _blocks.3._bn0.weight
# 동결된 층: _blocks.3._bn0.bias
# 동결된 층: _blocks.3._depthwise_conv.weight
# 동결된 층: _blocks.3._bn1.weight
# 동결된 층: _blocks.3._bn1.bias
# 동결된 층: _blocks.3._se_reduce.weight
# 동결된 층: _blocks.3._se_reduce.bias
# 동결된 층: _blocks.3._se_expand.weight
# 동결된 층: _blocks.3._se_expand.bias
# 동결된 층: _blocks.3._project_conv.weight
# 동결된 층: _blocks.3._bn2.weight
# 동결된 층: _blocks.3._bn2.bias
# 동결된 층: _blocks.4._expand_conv.weight
# 동결된 층: _blocks.4._bn0.weight
# 동결된 층: _blocks.4._bn0.bias
# 동결된 층: _blocks.4._depthwise_conv.weight
# 동결된 층: _blocks.4._bn1.weight
# 동결된 층: _blocks.4._bn1.bias
# 동결된 층: _blocks.4._se_reduce.weight
# 동결된 층: _blocks.4._se_reduce.bias
# 동결된 층: _blocks.4._se_expand.weight
# 동결된 층: _blocks.4._se_expand.bias
# 동결된 층: _blocks.4._project_conv.weight
# 동결된 층: _blocks.4._bn2.weight
# 동결된 층: _blocks.4._bn2.bias
# 동결된 층: _blocks.5._expand_conv.weight
# 동결된 층: _blocks.5._bn0.weight
# 동결된 층: _blocks.5._bn0.bias
# 동결된 층: _blocks.5._depthwise_conv.weight
# 동결된 층: _blocks.5._bn1.weight
# 동결된 층: _blocks.5._bn1.bias
# 동결된 층: _blocks.5._se_reduce.weight
# 동결된 층: _blocks.5._se_reduce.bias
# 동결된 층: _blocks.5._se_expand.weight
# 동결된 층: _blocks.5._se_expand.bias
# 동결된 층: _blocks.5._project_conv.weight
# 동결된 층: _blocks.5._bn2.weight
# 동결된 층: _blocks.5._bn2.bias
# 동결된 층: _blocks.6._expand_conv.weight
# 동결된 층: _blocks.6._bn0.weight
# 동결된 층: _blocks.6._bn0.bias
# 동결된 층: _blocks.6._depthwise_conv.weight
# 동결된 층: _blocks.6._bn1.weight
# 동결된 층: _blocks.6._bn1.bias
# 동결된 층: _blocks.6._se_reduce.weight
# 동결된 층: _blocks.6._se_reduce.bias
# 동결된 층: _blocks.6._se_expand.weight
# 동결된 층: _blocks.6._se_expand.bias
# 동결된 층: _blocks.6._project_conv.weight
# 동결된 층: _blocks.6._bn2.weight
# 동결된 층: _blocks.6._bn2.bias
# 동결된 층: _blocks.7._expand_conv.weight
# 동결된 층: _blocks.7._bn0.weight
# 동결된 층: _blocks.7._bn0.bias
# 동결된 층: _blocks.7._depthwise_conv.weight
# 동결된 층: _blocks.7._bn1.weight
# 동결된 층: _blocks.7._bn1.bias
# 동결된 층: _blocks.7._se_reduce.weight
# 동결된 층: _blocks.7._se_reduce.bias
# 동결된 층: _blocks.7._se_expand.weight
# 동결된 층: _blocks.7._se_expand.bias
# 동결된 층: _blocks.7._project_conv.weight
# 동결된 층: _blocks.7._bn2.weight
# 동결된 층: _blocks.7._bn2.bias
# 동결된 층: _blocks.8._expand_conv.weight
# 동결된 층: _blocks.8._bn0.weight
# 동결된 층: _blocks.8._bn0.bias
# 동결된 층: _blocks.8._depthwise_conv.weight
# 동결된 층: _blocks.8._bn1.weight
# 동결된 층: _blocks.8._bn1.bias
# 동결된 층: _blocks.8._se_reduce.weight
# 동결된 층: _blocks.8._se_reduce.bias
# 동결된 층: _blocks.8._se_expand.weight
# 동결된 층: _blocks.8._se_expand.bias
# 동결된 층: _blocks.8._project_conv.weight
# 동결된 층: _blocks.8._bn2.weight
# 동결된 층: _blocks.8._bn2.bias
# 동결된 층: _blocks.9._expand_conv.weight
# 동결된 층: _blocks.9._bn0.weight
# 동결된 층: _blocks.9._bn0.bias
# 동결된 층: _blocks.9._depthwise_conv.weight
# 동결된 층: _blocks.9._bn1.weight
# 동결된 층: _blocks.9._bn1.bias
# 동결된 층: _blocks.9._se_reduce.weight
# 동결된 층: _blocks.9._se_reduce.bias
# 동결된 층: _blocks.9._se_expand.weight
# 동결된 층: _blocks.9._se_expand.bias
# 동결된 층: _blocks.9._project_conv.weight
# 동결된 층: _blocks.9._bn2.weight
# 동결된 층: _blocks.9._bn2.bias
# 동결된 층: _blocks.10._expand_conv.weight
# 동결된 층: _blocks.10._bn0.weight
# 동결된 층: _blocks.10._bn0.bias
# 동결된 층: _blocks.10._depthwise_conv.weight
# 동결된 층: _blocks.10._bn1.weight
# 동결된 층: _blocks.10._bn1.bias
# 동결된 층: _blocks.10._se_reduce.weight
# 동결된 층: _blocks.10._se_reduce.bias
# 동결된 층: _blocks.10._se_expand.weight
# 동결된 층: _blocks.10._se_expand.bias
# 동결된 층: _blocks.10._project_conv.weight
# 동결된 층: _blocks.10._bn2.weight
# 동결된 층: _blocks.10._bn2.bias
# 동결된 층: _blocks.11._expand_conv.weight
# 동결된 층: _blocks.11._bn0.weight
# 동결된 층: _blocks.11._bn0.bias
# 동결된 층: _blocks.11._depthwise_conv.weight
# 동결된 층: _blocks.11._bn1.weight
# 동결된 층: _blocks.11._bn1.bias
# 동결된 층: _blocks.11._se_reduce.weight
# 동결된 층: _blocks.11._se_reduce.bias
# 동결된 층: _blocks.11._se_expand.weight
# 동결된 층: _blocks.11._se_expand.bias
# 동결된 층: _blocks.11._project_conv.weight
# 동결된 층: _blocks.11._bn2.weight
# 동결된 층: _blocks.11._bn2.bias
# 동결된 층: _blocks.12._expand_conv.weight
# 동결된 층: _blocks.12._bn0.weight
# 동결된 층: _blocks.12._bn0.bias
# 동결된 층: _blocks.12._depthwise_conv.weight
# 동결된 층: _blocks.12._bn1.weight
# 동결된 층: _blocks.12._bn1.bias
# 동결된 층: _blocks.12._se_reduce.weight
# 동결된 층: _blocks.12._se_reduce.bias
# 동결된 층: _blocks.12._se_expand.weight
# 동결된 층: _blocks.12._se_expand.bias
# 동결된 층: _blocks.12._project_conv.weight
# 동결된 층: _blocks.12._bn2.weight
# 동결된 층: _blocks.12._bn2.bias
# 동결된 층: _blocks.13._expand_conv.weight
# 동결된 층: _blocks.13._bn0.weight
# 동결된 층: _blocks.13._bn0.bias
# 동결된 층: _blocks.13._depthwise_conv.weight
# 동결된 층: _blocks.13._bn1.weight
# 동결된 층: _blocks.13._bn1.bias
# 동결된 층: _blocks.13._se_reduce.weight
# 동결된 층: _blocks.13._se_reduce.bias
# 동결된 층: _blocks.13._se_expand.weight
# 동결된 층: _blocks.13._se_expand.bias
# 동결된 층: _blocks.13._project_conv.weight
# 동결된 층: _blocks.13._bn2.weight
# 동결된 층: _blocks.13._bn2.bias
# 동결된 층: _blocks.14._expand_conv.weight
# 동결된 층: _blocks.14._bn0.weight
# 동결된 층: _blocks.14._bn0.bias
# 동결된 층: _blocks.14._depthwise_conv.weight
# 동결된 층: _blocks.14._bn1.weight
# 동결된 층: _blocks.14._bn1.bias
# 동결된 층: _blocks.14._se_reduce.weight
# 동결된 층: _blocks.14._se_reduce.bias
# 동결된 층: _blocks.14._se_expand.weight
# 동결된 층: _blocks.14._se_expand.bias
# 동결된 층: _blocks.14._project_conv.weight
# 동결된 층: _blocks.14._bn2.weight
# 동결된 층: _blocks.14._bn2.bias
# 동결된 층: _blocks.15._expand_conv.weight
# 동결된 층: _blocks.15._bn0.weight
# 동결된 층: _blocks.15._bn0.bias
# 동결된 층: _blocks.15._depthwise_conv.weight
# 동결된 층: _blocks.15._bn1.weight
# 동결된 층: _blocks.15._bn1.bias
# 동결된 층: _blocks.15._se_reduce.weight
# 동결된 층: _blocks.15._se_reduce.bias
# 동결된 층: _blocks.15._se_expand.weight
# 동결된 층: _blocks.15._se_expand.bias
# 동결된 층: _blocks.15._project_conv.weight
# 동결된 층: _blocks.15._bn2.weight
# 동결된 층: _blocks.15._bn2.bias
# 동결된 층: _blocks.16._expand_conv.weight
# 동결된 층: _blocks.16._bn0.weight
# 동결된 층: _blocks.16._bn0.bias
# 동결된 층: _blocks.16._depthwise_conv.weight
# 동결된 층: _blocks.16._bn1.weight
# 동결된 층: _blocks.16._bn1.bias
# 동결된 층: _blocks.16._se_reduce.weight
# 동결된 층: _blocks.16._se_reduce.bias
# 동결된 층: _blocks.16._se_expand.weight
# 동결된 층: _blocks.16._se_expand.bias
# 동결된 층: _blocks.16._project_conv.weight
# 동결된 층: _blocks.16._bn2.weight
# 동결된 층: _blocks.16._bn2.bias
# 동결된 층: _blocks.17._expand_conv.weight
# 동결된 층: _blocks.17._bn0.weight
# 동결된 층: _blocks.17._bn0.bias
# 동결된 층: _blocks.17._depthwise_conv.weight
# 동결된 층: _blocks.17._bn1.weight
# 동결된 층: _blocks.17._bn1.bias
# 동결된 층: _blocks.17._se_reduce.weight
# 동결된 층: _blocks.17._se_reduce.bias
# 동결된 층: _blocks.17._se_expand.weight
# 동결된 층: _blocks.17._se_expand.bias
# 동결된 층: _blocks.17._project_conv.weight
# 동결된 층: _blocks.17._bn2.weight
# 동결된 층: _blocks.17._bn2.bias
# 동결된 층: _blocks.18._expand_conv.weight
# 동결된 층: _blocks.18._bn0.weight
# 동결된 층: _blocks.18._bn0.bias
# 동결된 층: _blocks.18._depthwise_conv.weight
# 동결된 층: _blocks.18._bn1.weight
# 동결된 층: _blocks.18._bn1.bias
# 동결된 층: _blocks.18._se_reduce.weight
# 동결된 층: _blocks.18._se_reduce.bias
# 동결된 층: _blocks.18._se_expand.weight
# 동결된 층: _blocks.18._se_expand.bias
# 동결된 층: _blocks.18._project_conv.weight
# 동결된 층: _blocks.18._bn2.weight
# 동결된 층: _blocks.18._bn2.bias
# 동결된 층: _blocks.19._expand_conv.weight
# 동결된 층: _blocks.19._bn0.weight
# 동결된 층: _blocks.19._bn0.bias
# 동결된 층: _blocks.19._depthwise_conv.weight
# 동결된 층: _blocks.19._bn1.weight
# 동결된 층: _blocks.19._bn1.bias
# 동결된 층: _blocks.19._se_reduce.weight
# 동결된 층: _blocks.19._se_reduce.bias
# 동결된 층: _blocks.19._se_expand.weight
# 동결된 층: _blocks.19._se_expand.bias
# 동결된 층: _blocks.19._project_conv.weight
# 동결된 층: _blocks.19._bn2.weight
# 동결된 층: _blocks.19._bn2.bias
# 학습 대상인 층: _blocks.20._expand_conv.weight
# 학습 대상인 층: _blocks.20._bn0.weight
# 학습 대상인 층: _blocks.20._bn0.bias
# 학습 대상인 층: _blocks.20._depthwise_conv.weight
# 학습 대상인 층: _blocks.20._bn1.weight
# 학습 대상인 층: _blocks.20._bn1.bias
# 학습 대상인 층: _blocks.20._se_reduce.weight
# 학습 대상인 층: _blocks.20._se_reduce.bias
# 학습 대상인 층: _blocks.20._se_expand.weight
# 학습 대상인 층: _blocks.20._se_expand.bias
# 학습 대상인 층: _blocks.20._project_conv.weight
# 학습 대상인 층: _blocks.20._bn2.weight
# 학습 대상인 층: _blocks.20._bn2.bias
# 학습 대상인 층: _blocks.21._expand_conv.weight
# 학습 대상인 층: _blocks.21._bn0.weight
# 학습 대상인 층: _blocks.21._bn0.bias
# 학습 대상인 층: _blocks.21._depthwise_conv.weight
# 학습 대상인 층: _blocks.21._bn1.weight
# 학습 대상인 층: _blocks.21._bn1.bias
# 학습 대상인 층: _blocks.21._se_reduce.weight
# 학습 대상인 층: _blocks.21._se_reduce.bias
# 학습 대상인 층: _blocks.21._se_expand.weight
# 학습 대상인 층: _blocks.21._se_expand.bias
# 학습 대상인 층: _blocks.21._project_conv.weight
# 학습 대상인 층: _blocks.21._bn2.weight
# 학습 대상인 층: _blocks.21._bn2.bias
# 학습 대상인 층: _blocks.22._expand_conv.weight
# 학습 대상인 층: _blocks.22._bn0.weight
# 학습 대상인 층: _blocks.22._bn0.bias
# 학습 대상인 층: _blocks.22._depthwise_conv.weight
# 학습 대상인 층: _blocks.22._bn1.weight
# 학습 대상인 층: _blocks.22._bn1.bias
# 학습 대상인 층: _blocks.22._se_reduce.weight
# 학습 대상인 층: _blocks.22._se_reduce.bias
# 학습 대상인 층: _blocks.22._se_expand.weight
# 학습 대상인 층: _blocks.22._se_expand.bias
# 학습 대상인 층: _blocks.22._project_conv.weight
# 학습 대상인 층: _blocks.22._bn2.weight
# 학습 대상인 층: _blocks.22._bn2.bias
# 학습 대상인 층: _conv_head.weight
# 학습 대상인 층: _bn1.weight
# 학습 대상인 층: _bn1.bias
# 학습 대상인 층: _fc.weight
# 학습 대상인 층: _fc.bias

# %% [markdown]
# ##### Acc and Loss 시각화

# %%
# 정확도 및 손실을 그래프로 시각화
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(effb1_train_acc_lst, label='Train Accuracy')
plt.plot(effb1_val_acc_lst, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(effb1_train_loss_lst, label='Train Loss')
plt.plot(effb1_val_loss_lst, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# #### fc.layer만 학습 ver

# %%
import time

# 학습 시작 시간 기록
start_time = time.time()

# 모델 불러오기
model_path = 'C://Users/user/Desktop/딥러닝/학습모델/full_마송_448_efficientb1_38_98.71.pth'

# 모델 정의
model = EfficientNet.from_name('efficientnet-b1', num_classes=2)
model.to(device)

# 저장된 모델 가중치 불러오기
checkpoint = torch.load(model_path, map_location=device)
model.load_state_dict(checkpoint['net'])

# 모델의 Convolution 층을 고정하고 마지막 분류 층만 학습 가능하도록 설정
start_training = False  # 학습 시작 플래그

for name, param in model.named_parameters():
    if '_fc' in name:  # '_fc' 층만 학습 가능하도록 설정
        start_training = True
    if start_training:
        param.requires_grad = True
    else:
        param.requires_grad = False

# 필요한 옵티마이저 정의
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=0.0001)

# 손실 함수 정의
criterion = nn.CrossEntropyLoss()

# 리스트 초기화
effb1_train_acc_lst = []
effb1_train_loss_lst = []
effb1_val_acc_lst = []
effb1_val_loss_lst = []

state = {}

# 모델 훈련
epochs = 50
for epoch in range(1, epochs+1):

    train_loss = 0
    total = 0
    correct = 0
    train_acc = 0

    model.train()

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)

        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()

        # 정확도 계산
        _, predicted = torch.max(outputs, 1)  # 가장 높은 확률을 가진 클래스 선택
        total += labels.size(0)
        train_acc += (predicted == labels).sum().item()

    train_loss = round(train_loss / len(train_loader), 3)  # 미니배치 수로 나누어 평균을 계산
    train_acc = round((train_acc / total) * 100, 2)  # 백분율로 변환

    print(f'Trainset {epoch}/{epochs} Loss: {train_loss}, Accuracy: {train_acc}%')
    effb1_train_acc_lst.append(train_acc)
    effb1_train_loss_lst.append(train_loss)

    # 검증 데이터셋에 대한 손실과 정확도 계산
    val_loss = 0
    val_total = 0
    val_correct = 0
    val_acc = 0

    model.eval()
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)

            val_loss += criterion(outputs, labels).item()

            _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0)
            val_acc += (predicted == labels).sum().item()

    val_loss = round(val_loss / len(val_loader), 3)  # 검증 데이터셋의 손실 평균 계산
    val_acc = round((val_acc / val_total) * 100, 2)  # 검증 데이터셋의 정확도 계산

    print(f'Validation {epoch}/{epochs} Loss: {val_loss}, Accuracy: {val_acc}%')
    print()

    effb1_val_acc_lst.append(val_acc)
    effb1_val_loss_lst.append(val_loss)

    if np.max(effb1_val_acc_lst) <= val_acc:
        state['epoch'] = epoch
        state['net'] = model.state_dict()

        state['train_loss'] = train_loss
        state['val_loss'] = val_loss

        state['train_acc'] = train_acc
        state['val_acc'] = val_acc

end_time = time.time()

# 전체 학습 시간 계산 (종료 시간 - 시작 시간)
training_time_seconds = end_time - start_time

# 시, 분, 초로 변환
training_time_minutes = training_time_seconds // 60
training_time_hours = training_time_minutes // 60

print(f"Total training time: {training_time_seconds} seconds")
print(f"Total training time: {training_time_minutes} minutes")
print(f"Total training time: {training_time_hours} hours")
print(f"Total training time: {training_time_hours} H {training_time_minutes - (60 * training_time_hours)} m")

# 모델 저장
torch.save(state, 'C://Users/user/Desktop/딥러닝/학습모델/fclayer_김김_448_efficientb1_{}_{}.pth'.format(str(state['epoch']), str(state['val_acc'])))
# Out:
# Trainset 1/50 Loss: 3.348, Accuracy: 50.51%
# Validation 1/50 Loss: 3.384, Accuracy: 47.94%
#
# Trainset 2/50 Loss: 1.453, Accuracy: 51.17%
# Validation 2/50 Loss: 0.895, Accuracy: 50.81%
#
# Trainset 3/50 Loss: 0.7, Accuracy: 55.76%
# Validation 3/50 Loss: 0.701, Accuracy: 60.68%
#
# Trainset 4/50 Loss: 0.673, Accuracy: 61.32%
# Validation 4/50 Loss: 0.699, Accuracy: 62.3%
#
# Trainset 5/50 Loss: 0.665, Accuracy: 63.36%
# Validation 5/50 Loss: 0.673, Accuracy: 64.81%
#
# Trainset 6/50 Loss: 0.659, Accuracy: 63.4%
# Validation 6/50 Loss: 0.65, Accuracy: 66.79%
#
# Trainset 7/50 Loss: 0.649, Accuracy: 67.06%
# Validation 7/50 Loss: 0.636, Accuracy: 68.58%
#
# Trainset 8/50 Loss: 0.637, Accuracy: 67.99%
# Validation 8/50 Loss: 0.624, Accuracy: 68.58%
#
# Trainset 9/50 Loss: 0.627, Accuracy: 68.92%
# Validation 9/50 Loss: 0.625, Accuracy: 68.76%
#
# Trainset 10/50 Loss: 0.627, Accuracy: 69.23%
# Validation 10/50 Loss: 0.614, Accuracy: 71.1%
#
# Trainset 11/50 Loss: 0.62, Accuracy: 70.6%
# Validation 11/50 Loss: 0.622, Accuracy: 70.02%
#
# Trainset 12/50 Loss: 0.609, Accuracy: 71.7%
# Validation 12/50 Loss: 0.595, Accuracy: 71.45%
#
# Trainset 13/50 Loss: 0.6, Accuracy: 71.39%
# Validation 13/50 Loss: 0.604, Accuracy: 72.35%
#
# Trainset 14/50 Loss: 0.598, Accuracy: 73.25%
# Validation 14/50 Loss: 0.594, Accuracy: 72.17%
#
# Trainset 15/50 Loss: 0.6, Accuracy: 71.61%
# Validation 15/50 Loss: 0.586, Accuracy: 72.53%
#
# Trainset 16/50 Loss: 0.593, Accuracy: 72.32%
# Validation 16/50 Loss: 0.585, Accuracy: 72.53%
#
# Trainset 17/50 Loss: 0.588, Accuracy: 72.23%
# Validation 17/50 Loss: 0.577, Accuracy: 73.61%
#
# Trainset 18/50 Loss: 0.58, Accuracy: 73.02%
# Validation 18/50 Loss: 0.587, Accuracy: 72.35%
#
# Trainset 19/50 Loss: 0.574, Accuracy: 73.82%
# Validation 19/50 Loss: 0.564, Accuracy: 72.71%
#
# Trainset 20/50 Loss: 0.577, Accuracy: 72.85%
# Validation 20/50 Loss: 0.569, Accuracy: 73.07%
#
# Trainset 21/50 Loss: 0.57, Accuracy: 73.69%
# Validation 21/50 Loss: 0.57, Accuracy: 73.43%
#
# Trainset 22/50 Loss: 0.563, Accuracy: 74.44%
# Validation 22/50 Loss: 0.572, Accuracy: 73.07%
#
# Trainset 23/50 Loss: 0.559, Accuracy: 74.66%
# Validation 23/50 Loss: 0.577, Accuracy: 73.43%
#
# Trainset 24/50 Loss: 0.566, Accuracy: 73.29%
# Validation 24/50 Loss: 0.563, Accuracy: 73.79%
#
# Trainset 25/50 Loss: 0.563, Accuracy: 73.91%
# Validation 25/50 Loss: 0.568, Accuracy: 73.61%
#
# Trainset 26/50 Loss: 0.559, Accuracy: 73.95%
# Validation 26/50 Loss: 0.571, Accuracy: 72.89%
#
# Trainset 27/50 Loss: 0.558, Accuracy: 74.61%
# Validation 27/50 Loss: 0.569, Accuracy: 73.43%
#
# Trainset 28/50 Loss: 0.541, Accuracy: 75.98%
# Validation 28/50 Loss: 0.544, Accuracy: 74.33%
#
# Trainset 29/50 Loss: 0.547, Accuracy: 75.1%
# Validation 29/50 Loss: 0.541, Accuracy: 73.43%
#
# Trainset 30/50 Loss: 0.542, Accuracy: 76.6%
# Validation 30/50 Loss: 0.55, Accuracy: 73.61%
#
# Trainset 31/50 Loss: 0.541, Accuracy: 75.58%
# Validation 31/50 Loss: 0.559, Accuracy: 74.15%
#
# Trainset 32/50 Loss: 0.543, Accuracy: 75.32%
# Validation 32/50 Loss: 0.562, Accuracy: 74.33%
#
# Trainset 33/50 Loss: 0.535, Accuracy: 77.17%
# Validation 33/50 Loss: 0.539, Accuracy: 74.15%
#
# Trainset 34/50 Loss: 0.541, Accuracy: 75.28%
# Validation 34/50 Loss: 0.554, Accuracy: 74.69%
#
# Trainset 35/50 Loss: 0.532, Accuracy: 75.19%
# Validation 35/50 Loss: 0.538, Accuracy: 74.51%
#
# Trainset 36/50 Loss: 0.547, Accuracy: 74.44%
# Validation 36/50 Loss: 0.545, Accuracy: 74.15%
#
# Trainset 37/50 Loss: 0.542, Accuracy: 75.5%
# Validation 37/50 Loss: 0.553, Accuracy: 75.04%
#
# Trainset 38/50 Loss: 0.538, Accuracy: 75.72%
# Validation 38/50 Loss: 0.552, Accuracy: 73.25%
#
# Trainset 39/50 Loss: 0.529, Accuracy: 75.67%
# Validation 39/50 Loss: 0.53, Accuracy: 74.87%
#
# Trainset 40/50 Loss: 0.526, Accuracy: 76.47%
# Validation 40/50 Loss: 0.527, Accuracy: 75.04%
#
# Trainset 41/50 Loss: 0.518, Accuracy: 76.91%
# Validation 41/50 Loss: 0.535, Accuracy: 75.04%
#
# Trainset 42/50 Loss: 0.529, Accuracy: 75.45%
# Validation 42/50 Loss: 0.541, Accuracy: 74.69%
#
# Trainset 43/50 Loss: 0.528, Accuracy: 76.07%
# Validation 43/50 Loss: 0.542, Accuracy: 74.69%
#
# Trainset 44/50 Loss: 0.516, Accuracy: 77.66%
# Validation 44/50 Loss: 0.55, Accuracy: 74.87%
#
# Trainset 45/50 Loss: 0.526, Accuracy: 76.03%
# Validation 45/50 Loss: 0.541, Accuracy: 75.04%
#
# Trainset 46/50 Loss: 0.514, Accuracy: 77.13%
# Validation 46/50 Loss: 0.533, Accuracy: 74.87%
#
# Trainset 47/50 Loss: 0.509, Accuracy: 78.19%
# Validation 47/50 Loss: 0.524, Accuracy: 75.4%
#
# Trainset 48/50 Loss: 0.524, Accuracy: 76.64%
# Validation 48/50 Loss: 0.527, Accuracy: 75.58%
#
# Trainset 49/50 Loss: 0.513, Accuracy: 77.09%
# Validation 49/50 Loss: 0.521, Accuracy: 75.4%
#
# Trainset 50/50 Loss: 0.512, Accuracy: 77.4%
# Validation 50/50 Loss: 0.551, Accuracy: 75.04%
#
# Total training time: 1454.0149819850922 seconds
# Total training time: 24.0 minutes
# Total training time: 0.0 hours
# Total training time: 0.0 H 24.0 m

# %%
for name, param in model.named_parameters():
    if param.requires_grad:
        print(f'학습 대상인 층: {name}')
    else:
        print(f'동결된 층: {name}')
# Out:
# 동결된 층: _conv_stem.weight
# 동결된 층: _bn0.weight
# 동결된 층: _bn0.bias
# 동결된 층: _blocks.0._depthwise_conv.weight
# 동결된 층: _blocks.0._bn1.weight
# 동결된 층: _blocks.0._bn1.bias
# 동결된 층: _blocks.0._se_reduce.weight
# 동결된 층: _blocks.0._se_reduce.bias
# 동결된 층: _blocks.0._se_expand.weight
# 동결된 층: _blocks.0._se_expand.bias
# 동결된 층: _blocks.0._project_conv.weight
# 동결된 층: _blocks.0._bn2.weight
# 동결된 층: _blocks.0._bn2.bias
# 동결된 층: _blocks.1._depthwise_conv.weight
# 동결된 층: _blocks.1._bn1.weight
# 동결된 층: _blocks.1._bn1.bias
# 동결된 층: _blocks.1._se_reduce.weight
# 동결된 층: _blocks.1._se_reduce.bias
# 동결된 층: _blocks.1._se_expand.weight
# 동결된 층: _blocks.1._se_expand.bias
# 동결된 층: _blocks.1._project_conv.weight
# 동결된 층: _blocks.1._bn2.weight
# 동결된 층: _blocks.1._bn2.bias
# 동결된 층: _blocks.2._expand_conv.weight
# 동결된 층: _blocks.2._bn0.weight
# 동결된 층: _blocks.2._bn0.bias
# 동결된 층: _blocks.2._depthwise_conv.weight
# 동결된 층: _blocks.2._bn1.weight
# 동결된 층: _blocks.2._bn1.bias
# 동결된 층: _blocks.2._se_reduce.weight
# 동결된 층: _blocks.2._se_reduce.bias
# 동결된 층: _blocks.2._se_expand.weight
# 동결된 층: _blocks.2._se_expand.bias
# 동결된 층: _blocks.2._project_conv.weight
# 동결된 층: _blocks.2._bn2.weight
# 동결된 층: _blocks.2._bn2.bias
# 동결된 층: _blocks.3._expand_conv.weight
# 동결된 층: _blocks.3._bn0.weight
# 동결된 층: _blocks.3._bn0.bias
# 동결된 층: _blocks.3._depthwise_conv.weight
# 동결된 층: _blocks.3._bn1.weight
# 동결된 층: _blocks.3._bn1.bias
# 동결된 층: _blocks.3._se_reduce.weight
# 동결된 층: _blocks.3._se_reduce.bias
# 동결된 층: _blocks.3._se_expand.weight
# 동결된 층: _blocks.3._se_expand.bias
# 동결된 층: _blocks.3._project_conv.weight
# 동결된 층: _blocks.3._bn2.weight
# 동결된 층: _blocks.3._bn2.bias
# 동결된 층: _blocks.4._expand_conv.weight
# 동결된 층: _blocks.4._bn0.weight
# 동결된 층: _blocks.4._bn0.bias
# 동결된 층: _blocks.4._depthwise_conv.weight
# 동결된 층: _blocks.4._bn1.weight
# 동결된 층: _blocks.4._bn1.bias
# 동결된 층: _blocks.4._se_reduce.weight
# 동결된 층: _blocks.4._se_reduce.bias
# 동결된 층: _blocks.4._se_expand.weight
# 동결된 층: _blocks.4._se_expand.bias
# 동결된 층: _blocks.4._project_conv.weight
# 동결된 층: _blocks.4._bn2.weight
# 동결된 층: _blocks.4._bn2.bias
# 동결된 층: _blocks.5._expand_conv.weight
# 동결된 층: _blocks.5._bn0.weight
# 동결된 층: _blocks.5._bn0.bias
# 동결된 층: _blocks.5._depthwise_conv.weight
# 동결된 층: _blocks.5._bn1.weight
# 동결된 층: _blocks.5._bn1.bias
# 동결된 층: _blocks.5._se_reduce.weight
# 동결된 층: _blocks.5._se_reduce.bias
# 동결된 층: _blocks.5._se_expand.weight
# 동결된 층: _blocks.5._se_expand.bias
# 동결된 층: _blocks.5._project_conv.weight
# 동결된 층: _blocks.5._bn2.weight
# 동결된 층: _blocks.5._bn2.bias
# 동결된 층: _blocks.6._expand_conv.weight
# 동결된 층: _blocks.6._bn0.weight
# 동결된 층: _blocks.6._bn0.bias
# 동결된 층: _blocks.6._depthwise_conv.weight
# 동결된 층: _blocks.6._bn1.weight
# 동결된 층: _blocks.6._bn1.bias
# 동결된 층: _blocks.6._se_reduce.weight
# 동결된 층: _blocks.6._se_reduce.bias
# 동결된 층: _blocks.6._se_expand.weight
# 동결된 층: _blocks.6._se_expand.bias
# 동결된 층: _blocks.6._project_conv.weight
# 동결된 층: _blocks.6._bn2.weight
# 동결된 층: _blocks.6._bn2.bias
# 동결된 층: _blocks.7._expand_conv.weight
# 동결된 층: _blocks.7._bn0.weight
# 동결된 층: _blocks.7._bn0.bias
# 동결된 층: _blocks.7._depthwise_conv.weight
# 동결된 층: _blocks.7._bn1.weight
# 동결된 층: _blocks.7._bn1.bias
# 동결된 층: _blocks.7._se_reduce.weight
# 동결된 층: _blocks.7._se_reduce.bias
# 동결된 층: _blocks.7._se_expand.weight
# 동결된 층: _blocks.7._se_expand.bias
# 동결된 층: _blocks.7._project_conv.weight
# 동결된 층: _blocks.7._bn2.weight
# 동결된 층: _blocks.7._bn2.bias
# 동결된 층: _blocks.8._expand_conv.weight
# 동결된 층: _blocks.8._bn0.weight
# 동결된 층: _blocks.8._bn0.bias
# 동결된 층: _blocks.8._depthwise_conv.weight
# 동결된 층: _blocks.8._bn1.weight
# 동결된 층: _blocks.8._bn1.bias
# 동결된 층: _blocks.8._se_reduce.weight
# 동결된 층: _blocks.8._se_reduce.bias
# 동결된 층: _blocks.8._se_expand.weight
# 동결된 층: _blocks.8._se_expand.bias
# 동결된 층: _blocks.8._project_conv.weight
# 동결된 층: _blocks.8._bn2.weight
# 동결된 층: _blocks.8._bn2.bias
# 동결된 층: _blocks.9._expand_conv.weight
# 동결된 층: _blocks.9._bn0.weight
# 동결된 층: _blocks.9._bn0.bias
# 동결된 층: _blocks.9._depthwise_conv.weight
# 동결된 층: _blocks.9._bn1.weight
# 동결된 층: _blocks.9._bn1.bias
# 동결된 층: _blocks.9._se_reduce.weight
# 동결된 층: _blocks.9._se_reduce.bias
# 동결된 층: _blocks.9._se_expand.weight
# 동결된 층: _blocks.9._se_expand.bias
# 동결된 층: _blocks.9._project_conv.weight
# 동결된 층: _blocks.9._bn2.weight
# 동결된 층: _blocks.9._bn2.bias
# 동결된 층: _blocks.10._expand_conv.weight
# 동결된 층: _blocks.10._bn0.weight
# 동결된 층: _blocks.10._bn0.bias
# 동결된 층: _blocks.10._depthwise_conv.weight
# 동결된 층: _blocks.10._bn1.weight
# 동결된 층: _blocks.10._bn1.bias
# 동결된 층: _blocks.10._se_reduce.weight
# 동결된 층: _blocks.10._se_reduce.bias
# 동결된 층: _blocks.10._se_expand.weight
# 동결된 층: _blocks.10._se_expand.bias
# 동결된 층: _blocks.10._project_conv.weight
# 동결된 층: _blocks.10._bn2.weight
# 동결된 층: _blocks.10._bn2.bias
# 동결된 층: _blocks.11._expand_conv.weight
# 동결된 층: _blocks.11._bn0.weight
# 동결된 층: _blocks.11._bn0.bias
# 동결된 층: _blocks.11._depthwise_conv.weight
# 동결된 층: _blocks.11._bn1.weight
# 동결된 층: _blocks.11._bn1.bias
# 동결된 층: _blocks.11._se_reduce.weight
# 동결된 층: _blocks.11._se_reduce.bias
# 동결된 층: _blocks.11._se_expand.weight
# 동결된 층: _blocks.11._se_expand.bias
# 동결된 층: _blocks.11._project_conv.weight
# 동결된 층: _blocks.11._bn2.weight
# 동결된 층: _blocks.11._bn2.bias
# 동결된 층: _blocks.12._expand_conv.weight
# 동결된 층: _blocks.12._bn0.weight
# 동결된 층: _blocks.12._bn0.bias
# 동결된 층: _blocks.12._depthwise_conv.weight
# 동결된 층: _blocks.12._bn1.weight
# 동결된 층: _blocks.12._bn1.bias
# 동결된 층: _blocks.12._se_reduce.weight
# 동결된 층: _blocks.12._se_reduce.bias
# 동결된 층: _blocks.12._se_expand.weight
# 동결된 층: _blocks.12._se_expand.bias
# 동결된 층: _blocks.12._project_conv.weight
# 동결된 층: _blocks.12._bn2.weight
# 동결된 층: _blocks.12._bn2.bias
# 동결된 층: _blocks.13._expand_conv.weight
# 동결된 층: _blocks.13._bn0.weight
# 동결된 층: _blocks.13._bn0.bias
# 동결된 층: _blocks.13._depthwise_conv.weight
# 동결된 층: _blocks.13._bn1.weight
# 동결된 층: _blocks.13._bn1.bias
# 동결된 층: _blocks.13._se_reduce.weight
# 동결된 층: _blocks.13._se_reduce.bias
# 동결된 층: _blocks.13._se_expand.weight
# 동결된 층: _blocks.13._se_expand.bias
# 동결된 층: _blocks.13._project_conv.weight
# 동결된 층: _blocks.13._bn2.weight
# 동결된 층: _blocks.13._bn2.bias
# 동결된 층: _blocks.14._expand_conv.weight
# 동결된 층: _blocks.14._bn0.weight
# 동결된 층: _blocks.14._bn0.bias
# 동결된 층: _blocks.14._depthwise_conv.weight
# 동결된 층: _blocks.14._bn1.weight
# 동결된 층: _blocks.14._bn1.bias
# 동결된 층: _blocks.14._se_reduce.weight
# 동결된 층: _blocks.14._se_reduce.bias
# 동결된 층: _blocks.14._se_expand.weight
# 동결된 층: _blocks.14._se_expand.bias
# 동결된 층: _blocks.14._project_conv.weight
# 동결된 층: _blocks.14._bn2.weight
# 동결된 층: _blocks.14._bn2.bias
# 동결된 층: _blocks.15._expand_conv.weight
# 동결된 층: _blocks.15._bn0.weight
# 동결된 층: _blocks.15._bn0.bias
# 동결된 층: _blocks.15._depthwise_conv.weight
# 동결된 층: _blocks.15._bn1.weight
# 동결된 층: _blocks.15._bn1.bias
# 동결된 층: _blocks.15._se_reduce.weight
# 동결된 층: _blocks.15._se_reduce.bias
# 동결된 층: _blocks.15._se_expand.weight
# 동결된 층: _blocks.15._se_expand.bias
# 동결된 층: _blocks.15._project_conv.weight
# 동결된 층: _blocks.15._bn2.weight
# 동결된 층: _blocks.15._bn2.bias
# 동결된 층: _blocks.16._expand_conv.weight
# 동결된 층: _blocks.16._bn0.weight
# 동결된 층: _blocks.16._bn0.bias
# 동결된 층: _blocks.16._depthwise_conv.weight
# 동결된 층: _blocks.16._bn1.weight
# 동결된 층: _blocks.16._bn1.bias
# 동결된 층: _blocks.16._se_reduce.weight
# 동결된 층: _blocks.16._se_reduce.bias
# 동결된 층: _blocks.16._se_expand.weight
# 동결된 층: _blocks.16._se_expand.bias
# 동결된 층: _blocks.16._project_conv.weight
# 동결된 층: _blocks.16._bn2.weight
# 동결된 층: _blocks.16._bn2.bias
# 동결된 층: _blocks.17._expand_conv.weight
# 동결된 층: _blocks.17._bn0.weight
# 동결된 층: _blocks.17._bn0.bias
# 동결된 층: _blocks.17._depthwise_conv.weight
# 동결된 층: _blocks.17._bn1.weight
# 동결된 층: _blocks.17._bn1.bias
# 동결된 층: _blocks.17._se_reduce.weight
# 동결된 층: _blocks.17._se_reduce.bias
# 동결된 층: _blocks.17._se_expand.weight
# 동결된 층: _blocks.17._se_expand.bias
# 동결된 층: _blocks.17._project_conv.weight
# 동결된 층: _blocks.17._bn2.weight
# 동결된 층: _blocks.17._bn2.bias
# 동결된 층: _blocks.18._expand_conv.weight
# 동결된 층: _blocks.18._bn0.weight
# 동결된 층: _blocks.18._bn0.bias
# 동결된 층: _blocks.18._depthwise_conv.weight
# 동결된 층: _blocks.18._bn1.weight
# 동결된 층: _blocks.18._bn1.bias
# 동결된 층: _blocks.18._se_reduce.weight
# 동결된 층: _blocks.18._se_reduce.bias
# 동결된 층: _blocks.18._se_expand.weight
# 동결된 층: _blocks.18._se_expand.bias
# 동결된 층: _blocks.18._project_conv.weight
# 동결된 층: _blocks.18._bn2.weight
# 동결된 층: _blocks.18._bn2.bias
# 동결된 층: _blocks.19._expand_conv.weight
# 동결된 층: _blocks.19._bn0.weight
# 동결된 층: _blocks.19._bn0.bias
# 동결된 층: _blocks.19._depthwise_conv.weight
# 동결된 층: _blocks.19._bn1.weight
# 동결된 층: _blocks.19._bn1.bias
# 동결된 층: _blocks.19._se_reduce.weight
# 동결된 층: _blocks.19._se_reduce.bias
# 동결된 층: _blocks.19._se_expand.weight
# 동결된 층: _blocks.19._se_expand.bias
# 동결된 층: _blocks.19._project_conv.weight
# 동결된 층: _blocks.19._bn2.weight
# 동결된 층: _blocks.19._bn2.bias
# 동결된 층: _blocks.20._expand_conv.weight
# 동결된 층: _blocks.20._bn0.weight
# 동결된 층: _blocks.20._bn0.bias
# 동결된 층: _blocks.20._depthwise_conv.weight
# 동결된 층: _blocks.20._bn1.weight
# 동결된 층: _blocks.20._bn1.bias
# 동결된 층: _blocks.20._se_reduce.weight
# 동결된 층: _blocks.20._se_reduce.bias
# 동결된 층: _blocks.20._se_expand.weight
# 동결된 층: _blocks.20._se_expand.bias
# 동결된 층: _blocks.20._project_conv.weight
# 동결된 층: _blocks.20._bn2.weight
# 동결된 층: _blocks.20._bn2.bias
# 동결된 층: _blocks.21._expand_conv.weight
# 동결된 층: _blocks.21._bn0.weight
# 동결된 층: _blocks.21._bn0.bias
# 동결된 층: _blocks.21._depthwise_conv.weight
# 동결된 층: _blocks.21._bn1.weight
# 동결된 층: _blocks.21._bn1.bias
# 동결된 층: _blocks.21._se_reduce.weight
# 동결된 층: _blocks.21._se_reduce.bias
# 동결된 층: _blocks.21._se_expand.weight
# 동결된 층: _blocks.21._se_expand.bias
# 동결된 층: _blocks.21._project_conv.weight
# 동결된 층: _blocks.21._bn2.weight
# 동결된 층: _blocks.21._bn2.bias
# 동결된 층: _blocks.22._expand_conv.weight
# 동결된 층: _blocks.22._bn0.weight
# 동결된 층: _blocks.22._bn0.bias
# 동결된 층: _blocks.22._depthwise_conv.weight
# 동결된 층: _blocks.22._bn1.weight
# 동결된 층: _blocks.22._bn1.bias
# 동결된 층: _blocks.22._se_reduce.weight
# 동결된 층: _blocks.22._se_reduce.bias
# 동결된 층: _blocks.22._se_expand.weight
# 동결된 층: _blocks.22._se_expand.bias
# 동결된 층: _blocks.22._project_conv.weight
# 동결된 층: _blocks.22._bn2.weight
# 동결된 층: _blocks.22._bn2.bias
# 동결된 층: _conv_head.weight
# 동결된 층: _bn1.weight
# 동결된 층: _bn1.bias
# 학습 대상인 층: _fc.weight
# 학습 대상인 층: _fc.bias

# %% [markdown]
# ##### Acc and Loss 시각화

# %%
# 정확도 및 손실을 그래프로 시각화
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(effb1_train_acc_lst, label='Train Accuracy')
plt.plot(effb1_val_acc_lst, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(effb1_train_loss_lst, label='Train Loss')
plt.plot(effb1_val_loss_lst, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ### 폴더 데이터 체크

# %%
import os
import torch
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from PIL import Image

# 모델 불러오기
model_path = '/content/drive/MyDrive/연예인 사진 분류/new_so_aug_448_efficientb1_26_96.27.pth'

# 모델 정의 (모델 아키텍처와 동일하게 정의해야 함)
model = EfficientNet.from_name('efficientnet-b1', num_classes=2)
model.to(device)

# 저장된 모델 가중치 불러오기
checkpoint = torch.load(model_path, map_location=device)
model.load_state_dict(checkpoint['net'])
model.eval()

# 폴더 경로 설정
image_folder = '/content/drive/MyDrive/얼굴분류/test'  # 이미지 파일들이 있는 폴더 경로

# 폴더 내의 모든 이미지 파일 리스트
image_files = [os.path.join(image_folder, file) for file in os.listdir(image_folder) if file.endswith(('.jpg', '.jpeg', '.png'))]

# 데이터 전처리 변환
transform = transforms.Compose([
    transforms.Resize((448, 448)),  # 모델에 맞는 이미지 크기로 조정
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

class_names = ["김태희", "김혜수"]

# 결과를 저장할 리스트 초기화
results = []

# 이미지 파일들에 대한 예측
for image_path in image_files:
    with torch.no_grad():
        image = Image.open(image_path).convert("RGB")
        image = transform(image).unsqueeze(0).to(device)

        output = model(image)
        probabilities = torch.softmax(output, dim=1)[0].cpu().numpy()
        predicted_class = np.argmax(probabilities)
        predicted_class_name = class_names[predicted_class]  # 예측 클래스 이름
        predicted_class_probs = dict(zip(class_names, probabilities))  # 클래스 이름과 확률을 딕셔너리로 저장

        results.append({
            'image_path': image_path,
            'predicted_class': predicted_class_name,
            'predicted_class_probs': predicted_class_probs
        })

# 시각화
images_per_page = 10
for i in range(0, len(results), images_per_page):
    plt.figure(figsize=(30, 20))
    for j, result in enumerate(results[i:i + images_per_page]):
        plt.subplot(5, 2, j + 1)
        image = Image.open(result['image_path'])
        plt.imshow(image)
        plt.title(f"Class: {result['predicted_class']}\nProbabilities: {result['predicted_class_probs']}")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 이미지 한장 체크

# %%
import os
import torch
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from PIL import Image

# 모델 불러오기
model_path = '/Users/taeyoung/Desktop/딥러닝/new_so_aug_448_efficientb1_26_96.27.pth'

# 모델 정의 (모델 아키텍처와 동일하게 정의해야 함)
model = EfficientNet.from_name('efficientnet-b1', num_classes=2)
model.to(device)

# 저장된 모델 가중치 불러오기
checkpoint = torch.load(model_path, map_location=device)
model.load_state_dict(checkpoint['net'])
model.eval()

# 이미지 파일 경로 설정
image_path = '/Users/taeyoung/Desktop/딥러닝/test/김태희_test_5.jpeg'  # 단일 이미지 파일 경로

# 데이터 전처리 변환
transform = transforms.Compose([
    transforms.Resize((448, 448)),  # 모델에 맞는 이미지 크기로 조정
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

class_names = ["김태희", "김혜수"]

# 이미지에 대한 예측
with torch.no_grad():
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)

    output = model(image)
    probabilities = torch.softmax(output, dim=1)[0].cpu().numpy()
    predicted_class = np.argmax(probabilities)
    predicted_class_name = class_names[predicted_class]  # 예측 클래스 이름
    predicted_class_probs = dict(zip(class_names, probabilities))  # 클래스 이름과 확률을 딕셔너리로 저장

# 시각화
plt.figure(figsize=(8, 4))
image = Image.open(image_path)
plt.imshow(image)
plt.title(f"Class: {predicted_class_name}\nProbabilities: {predicted_class_probs}")
plt.axis('off')
plt.show()

# %% [markdown]
# ### 테스트 데이터 체크

# %%
# import torch
# import torch.nn as nn
# from efficientnet_pytorch import EfficientNet
# import torch.optim as optim
# import matplotlib.pyplot as plt
# import numpy as np
# from PIL import Image


# # 저장된 모델 가중치 파일의 경로
# model_path = '/Users/taeyoung/Desktop/딥러닝/new_so_aug_448_efficientb1_26_96.27.pth'

# # 모델 정의
# model = EfficientNet.from_name('efficientnet-b1', num_classes=2)  # 4개의 클래스를 가진 모델로 수정
# model.to(device)

# checkpoint = torch.load(model_path, map_location=device)
# model.load_state_dict(checkpoint['net'], strict=False)

# # 출력층 변경
# model._fc = nn.Linear(model._fc.in_features, 4)
# model.eval()
# model.to(device)

# class_names = ["김태희", "김혜수", "마동석", "송중기"]

# results = []

# # 테스트 데이터에 대한 예측 및 확률 저장
# with torch.no_grad():
#     for images, labels in test_loader:
#         images, labels = images.to(device), labels.to(device)
#         outputs = model(images)

#         # 소프트맥스 함수를 사용하여 클래스별 예측 확률 계산
#         probs = torch.softmax(outputs, dim=1)
#         class_probs = probs.cpu().numpy()

#         for i in range(len(images)):
#             predicted_class_probs = dict(zip(class_names, class_probs[i]))
#             results.append({
#                 'predicted_class': class_names[np.argmax(class_probs[i])],
#                 'predicted_class_probs': predicted_class_probs
#             })

# # 이미지 시각화
# images_per_page = 10  # 한 페이지에 표시할 이미지 수
# num_pages = (len(results) + images_per_page - 1) // images_per_page

# for page in range(num_pages):
#     fig, axes = plt.subplots(images_per_page // 1, 1, figsize=(40, 40))
#     axes = axes.ravel()

#     for i in range(images_per_page):
#         index = page * images_per_page + i
#         if index < len(results):
#             predicted_class = results[index]['predicted_class']
#             predicted_class_probs = results[index]['predicted_class_probs']

#             # 이미지 파일 가져오기
#             image_path = test_loader.dataset.samples[index][0]
#             image = Image.open(image_path)

#             # 예측 확률을 소수점 두 자리까지 표시
#             formatted_probs = {k: f"{v:.2f}" for k, v in predicted_class_probs.items()}

#             # 이미지 시각화
#             axes[i].imshow(image)
#             axes[i].set_title(f'Predicted Class: {predicted_class}\nProbabilities: {formatted_probs}')
#             axes[i].axis('off')

#     plt.tight_layout()
#     plt.show()
